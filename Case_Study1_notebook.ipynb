# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Reading the dataset of cars

# %%
df=pd.read_csv('cars_data.csv')

# %% [markdown]
# # 2.Displaying the dataset

# %%
df
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # 3.Checking for the null values

# %%
df.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# The above zero values shows that there is no null value in the dataset

# %% [markdown]
# # 4.Plotting bar graph of Male Vs Female buyers participated in the sales.

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Nickname', 'Car Gender', 'Buyer Gender', 'Buyer Age',
#        'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
#        'Color', 'New Car', 'Purchase Date', 'Sale Price', 'Discount',
#        'Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'],
#       dtype='object')

# %% [markdown]
# Getting rid of the spcaes in the column name

# %%
for columns in df.columns:
    new_name=columns.replace(" ","_")
    df=df.rename(columns={columns:new_name})

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Nickname', 'Car_Gender', 'Buyer_Gender', 'Buyer_Age',
#        'Buzzword', 'Country', 'City', 'Dealer_Latitude', 'Dealer_Longitude',
#        'Color', 'New_Car', 'Purchase_Date', 'Sale_Price', 'Discount',
#        'Resell_Price', '5-yr_Depreciation', 'Top_Speed', '0-60_Time'],
#       dtype='object')

# %%
df["Buyer_Gender"].value_counts()
# Out:
# Female    5052
# Male      4948
# Name: Buyer_Gender, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df["Buyer_Gender"])
plt.show()
# Out:
# C:\Users\ollak\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 5.To find out the top 5 cars based on their Sale price

# %%
df1=df[['Make','Model','Sale_Price']]
df1.nlargest(10,'Sale_Price')
# Out:
#              Make      Model  Sale_Price
# 5984   Volkswagen  Jetta III    99997.65
# 1270         Audi         A6    99991.91
# 3460        Lexus         LX    99983.38
# 9032        Mazda       MX-6    99978.17
# 302         Lexus         ES    99973.44
# 7998  Lamborghini   Gallardo    99966.56
# 3718       Toyota    4Runner    99963.94
# 8490     Maserati        430    99947.94
# 9878        Honda   Passport    99943.77
# 2328    Chevrolet      Metro    99932.74

# %% [markdown]
# # Inference 1

# %% [markdown]
# The top 5 cars in sale are :
#
#   1.Volkswagen Jetta III
#
#   2.Audi A6
#
#   3.Lexus LX
#
#   4.Mazda MX-6
#
#   5.Lexus ES

# %% [markdown]
# #  6.To find out the least 5 cars based on Resell Price

# %%
df2=df.nsmallest(n=10, columns=['Resell_Price'])
new_df2=df2[['Make','Model','Resell_Price']]
new_df2
# Out:
#             Make        Model  Resell_Price
# 2446   Chevrolet         1500       2000.84
# 4933         GMC  Savana 1500       2005.44
# 566       Jaguar           XF       2014.09
# 2538  Mitsubishi       3000GT       2017.24
# 5869    Infiniti          G37       2017.83
# 6396  Mitsubishi   Challenger       2020.89
# 5197     Hyundai       Sonata       2021.75
# 8550     Pontiac   Grand Prix       2030.79
# 4475         BMW           X3       2032.28
# 3172       Honda      Element       2038.14

# %% [markdown]
# # Inference 2

# %% [markdown]
# The least 5 cars based on their resell value are:
#
#     1.Chevrolet 1500
#
#     2.GMC Savana 1500
#
#     3.Jaguar XF
#
#     4.Mitsubishi 3000GT
#
#     5.Infiniti G37
